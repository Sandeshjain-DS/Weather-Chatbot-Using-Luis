# %%
# !pip install -r requirements.txt
# Out:
# Collecting adal==1.2.1
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'c:\\programdata\\anaconda3\\lib\\site-packages\\certifi-2021.10.8-py3.8.egg-info\\dependency_links.txt'
# Consider using the `--user` option or check the permissions.
#   Downloading adal-1.2.1-py2.py3-none-any.whl (52 kB)
# Collecting aiohttp==3.6.2
#   Downloading aiohttp-3.6.2-py3-none-any.whl (441 kB)
# Collecting aiounittest==1.3.0
#   Downloading aiounittest-1.3.0.tar.gz (5.4 kB)
# Collecting applicationinsights==0.11.9
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting APScheduler==3.6.3
#   Downloading APScheduler-3.6.3-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: async-timeout==3.0.1 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (3.0.1)
# Collecting attrs==19.3.0
#   Downloading attrs-19.3.0-py2.py3-none-any.whl (39 kB)
# Collecting azure-cognitiveservices-language-luis==0.2.0
#   Downloading azure_cognitiveservices_language_luis-0.2.0-py2.py3-none-any.whl (244 kB)
# Collecting azure-common==1.1.25
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting azure-cosmos==3.1.2
#   Downloading azure_cosmos-3.1.2-py3-none-any.whl (140 kB)
# Collecting azure-storage-blob==2.1.0
#   Downloading azure_storage_blob-2.1.0-py2.py3-none-any.whl (88 kB)
# Collecting azure-storage-common==2.1.0
#   Downloading azure_storage_common-2.1.0-py2.py3-none-any.whl (47 kB)
# Collecting Babel==2.7.0
#   Downloading Babel-2.7.0-py2.py3-none-any.whl (8.4 MB)
# Collecting botbuilder-ai==4.8.0
#   Downloading botbuilder_ai-4.8.0-py3-none-any.whl (32 kB)
# Collecting botbuilder-applicationinsights==4.8.0
#   Downloading botbuilder_applicationinsights-4.8.0-py3-none-any.whl (18 kB)
# Collecting botbuilder-azure==4.8.0
#   Downloading botbuilder_azure-4.8.0-py3-none-any.whl (11 kB)
# Collecting botbuilder-core==4.8.0
#   Downloading botbuilder_core-4.8.0-py3-none-any.whl (84 kB)
# Collecting botbuilder-dialogs==4.8.0
#   Downloading botbuilder_dialogs-4.8.0-py3-none-any.whl (60 kB)
# Collecting botbuilder-schema==4.8.0
#   Downloading botbuilder_schema-4.8.0-py2.py3-none-any.whl (47 kB)
# Collecting botframework-connector==4.8.0
#   Downloading botframework_connector-4.8.0-py2.py3-none-any.whl (68 kB)
# Collecting certifi==2019.11.28
#   Downloading certifi-2019.11.28-py2.py3-none-any.whl (156 kB)
# Collecting cffi==1.14.0
#   Downloading cffi-1.14.0-cp38-cp38-win_amd64.whl (177 kB)
# Requirement already satisfied: chardet==3.0.4 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 23)) (3.0.4)
# Collecting Click==7.0
#   Downloading Click-7.0-py2.py3-none-any.whl (81 kB)
# Collecting colorhash==1.0.2
#   Downloading colorhash-1.0.2-py2.py3-none-any.whl (6.0 kB)
# Collecting configparser==4.0.2
#   Downloading configparser-4.0.2-py2.py3-none-any.whl (22 kB)
# Collecting cryptography==2.8
#   Downloading cryptography-2.8-cp38-cp38-win_amd64.whl (1.5 MB)
# Requirement already satisfied: cycler==0.10.0 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 28)) (0.10.0)
# Collecting datedelta==1.3
#   Downloading datedelta-1.3-py3-none-any.whl (6.7 kB)
# Collecting Django==2.2.6
#   Downloading Django-2.2.6-py3-none-any.whl (7.5 MB)
# Collecting djangorestframework==3.10.3
#   Downloading djangorestframework-3.10.3-py3-none-any.whl (909 kB)
# Collecting emoji==0.5.4
#   Downloading emoji-0.5.4.tar.gz (43 kB)
# Collecting Flask==1.1.1
#   Downloading Flask-1.1.1-py2.py3-none-any.whl (94 kB)
# Collecting Flask-Cors==3.0.8
#   Downloading Flask_Cors-3.0.8-py2.py3-none-any.whl (14 kB)
# Collecting Flask-MonitoringDashboard==3.0.6
#   Downloading Flask-MonitoringDashboard-3.0.6.tar.gz (217 kB)
# Collecting geojson==2.5.0
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Collecting grapheme==0.6.0
#   Downloading grapheme-0.6.0.tar.gz (207 kB)
# Collecting gunicorn==20.0.4
#   Downloading gunicorn-20.0.4-py2.py3-none-any.whl (77 kB)
# Collecting idna==2.8
#   Downloading idna-2.8-py2.py3-none-any.whl (58 kB)
# Collecting isodate==0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied: itsdangerous==1.1.0 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 41)) (1.1.0)
# Collecting Jinja2==2.11.0
#   Downloading Jinja2-2.11.0-py2.py3-none-any.whl (126 kB)
# Collecting jsonpickle==1.2
#   Downloading jsonpickle-1.2-py2.py3-none-any.whl (32 kB)
# Collecting kiwisolver==1.1.0
#   Downloading kiwisolver-1.1.0-cp38-none-win_amd64.whl (57 kB)
# Collecting kneed==0.5.3
#   Downloading kneed-0.5.3-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: MarkupSafe==1.1.1 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 46)) (1.1.1)
# Collecting msal==1.1.0
#   Downloading msal-1.1.0-py2.py3-none-any.whl (44 kB)
# Collecting msrest==0.6.10
#   Downloading msrest-0.6.10-py2.py3-none-any.whl (82 kB)
# Collecting msrestazure==0.6.3
#   Downloading msrestazure-0.6.3-py2.py3-none-any.whl (40 kB)
# Collecting multidict==4.7.5
#   Downloading multidict-4.7.5-cp38-cp38-win_amd64.whl (48 kB)
# Requirement already satisfied: multipledispatch==0.6.0 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 51)) (0.6.0)
# Requirement already satisfied: oauthlib==3.1.0 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 52)) (3.1.0)
# Collecting psutil==5.7.0
#   Downloading psutil-5.7.0-cp38-cp38-win_amd64.whl (235 kB)
# Requirement already satisfied: pycparser==2.20 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 54)) (2.20)
# Collecting PyJWT==1.5.3
#   Downloading PyJWT-1.5.3-py2.py3-none-any.whl (17 kB)
# Collecting pyowm==2.10.0
#   Downloading pyowm-2.10.0-py3-none-any.whl (3.7 MB)
# Collecting pyparsing==2.4.6
#   Downloading pyparsing-2.4.6-py2.py3-none-any.whl (67 kB)
# Requirement already satisfied: python-dateutil==2.8.1 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 58)) (2.8.1)
# Collecting pytz==2019.3
#   Downloading pytz-2019.3-py2.py3-none-any.whl (509 kB)
# Collecting recognizers-text==1.0.2a2
#   Downloading recognizers_text-1.0.2a2-py3-none-any.whl (14 kB)
# Collecting recognizers-text-choice==1.0.2a2
#   Downloading recognizers_text_choice-1.0.2a2-py3-none-any.whl (8.0 kB)
# Collecting recognizers-text-date-time==1.0.2a2
#   Downloading recognizers_text_date_time-1.0.2a2-py3-none-any.whl (248 kB)
# Collecting recognizers-text-number==1.0.2a2
#   Downloading recognizers_text_number-1.0.2a2-py3-none-any.whl (60 kB)
# Collecting recognizers-text-number-with-unit==1.0.2a2
#   Downloading recognizers_text_number_with_unit-1.0.2a2-py3-none-any.whl (75 kB)
# Collecting regex==2019.8.19
#   Downloading regex-2019.08.19-cp38-none-win_amd64.whl (325 kB)
# Collecting requests==2.22.0
#   Downloading requests-2.22.0-py2.py3-none-any.whl (57 kB)
# Requirement already satisfied: requests-oauthlib==1.3.0 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 67)) (1.3.0)
# Collecting six==1.14.0
#   Downloading six-1.14.0-py2.py3-none-any.whl (10 kB)
# Collecting SQLAlchemy==1.3.13
#   Downloading SQLAlchemy-1.3.13.tar.gz (6.0 MB)
# Collecting sqlparse==0.3.1
#   Downloading sqlparse-0.3.1-py2.py3-none-any.whl (40 kB)
# Collecting tzlocal==2.0.0
#   Downloading tzlocal-2.0.0-py2.py3-none-any.whl (15 kB)
# Collecting urllib3==1.25.8
#   Downloading urllib3-1.25.8-py2.py3-none-any.whl (125 kB)
# Collecting Werkzeug==0.16.1
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# Requirement already satisfied: wincertstore==0.2 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 74)) (0.2)
# Collecting yarl==1.4.2
#   Downloading yarl-1.4.2-cp38-cp38-win_amd64.whl (126 kB)
# Requirement already satisfied: setuptools>=0.7 in c:\programdata\anaconda3\lib\site-packages (from APScheduler==3.6.3->-r requirements.txt (line 5)) (50.3.1.post20201107)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from Flask-MonitoringDashboard==3.0.6->-r requirements.txt (line 35)) (1.19.2)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from kneed==0.5.3->-r requirements.txt (line 45)) (3.3.2)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from kneed==0.5.3->-r requirements.txt (line 45)) (1.5.2)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from kneed==0.5.3->-r requirements.txt (line 45)) (0.24.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->kneed==0.5.3->-r requirements.txt (line 45)) (8.0.1)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->kneed==0.5.3->-r requirements.txt (line 45)) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->kneed==0.5.3->-r requirements.txt (line 45)) (2.1.0)
# Building wheels for collected packages: aiounittest, emoji, Flask-MonitoringDashboard, grapheme, SQLAlchemy
#   Building wheel for aiounittest (setup.py): started
#   Building wheel for aiounittest (setup.py): finished with status 'done'
#   Created wheel for aiounittest: filename=aiounittest-1.3.0-py3-none-any.whl size=6730 sha256=26dc31f8e9f97242e148f19332019796cdcd9c2c4a28af01248fc0a5ff104646
#   Stored in directory: c:\users\waheguru\appdata\local\pip\cache\wheels\28\9b\c2\36cddfec3a08736bb94d40d8f9c39ccdf4e2727b81fd5ac10f
#   Building wheel for emoji (setup.py): started
#   Building wheel for emoji (setup.py): finished with status 'done'
#   Created wheel for emoji: filename=emoji-0.5.4-py3-none-any.whl size=42180 sha256=9ab905519ea98ab67f6e260b77fc70ffb3355712a8014d320a494f38d046e821
#   Stored in directory: c:\users\waheguru\appdata\local\pip\cache\wheels\22\d2\67\010d63edb25b9f0e7d5c181a4b77d9bdc9e027eb5562c4cc1d
#   Building wheel for Flask-MonitoringDashboard (setup.py): started
#   Building wheel for Flask-MonitoringDashboard (setup.py): finished with status 'done'
#   Created wheel for Flask-MonitoringDashboard: filename=Flask_MonitoringDashboard-3.0.6-py3-none-any.whl size=270180 sha256=577463f2ae35a42ac9728910a898f405390ed0b9115603a112f1daf29ced74e5
#   Stored in directory: c:\users\waheguru\appdata\local\pip\cache\wheels\28\e5\f2\dfee5768f7494c32e922118741bf5316b57dd3068c6c855384
#   Building wheel for grapheme (setup.py): started
#   Building wheel for grapheme (setup.py): finished with status 'done'
#   Created wheel for grapheme: filename=grapheme-0.6.0-py3-none-any.whl size=210101 sha256=03808c70e142fd27154b36be19525727a70d2ac98646842ef50195ba9dc24ac4
#   Stored in directory: c:\users\waheguru\appdata\local\pip\cache\wheels\2d\08\6b\126ea9009f7482fd53a78d0db2ece5aca70af8f4a30445386b
#   Building wheel for SQLAlchemy (setup.py): started
#   Building wheel for SQLAlchemy (setup.py): finished with status 'done'
#   Created wheel for SQLAlchemy: filename=SQLAlchemy-1.3.13-cp38-cp38-win_amd64.whl size=1171668 sha256=0584715caafa4df58ed25440a2f1272b806a7b3ac3591a07ae2e4e5aa787c3b6
#   Stored in directory: c:\users\waheguru\appdata\local\pip\cache\wheels\1b\5b\fe\df3abf130f4f66b437ea92eb98814d9d9fa80d70a6ee080b96
# Successfully built aiounittest emoji Flask-MonitoringDashboard grapheme SQLAlchemy
# Installing collected packages: certifi, urllib3, idna, requests, PyJWT, cffi, six, cryptography, adal, multidict, attrs, yarl, aiohttp, aiounittest, applicationinsights, pytz, tzlocal, APScheduler, azure-common, isodate, msrest, msrestazure, azure-cognitiveservices-language-luis, azure-cosmos, azure-storage-common, azure-storage-blob, Babel, botbuilder-schema, jsonpickle, msal, botframework-connector, botbuilder-core, botbuilder-ai, sqlparse, Django, Jinja2, Werkzeug, Click, Flask, djangorestframework, botbuilder-applicationinsights, botbuilder-azure, regex, emoji, recognizers-text, recognizers-text-number, recognizers-text-number-with-unit, datedelta, recognizers-text-date-time, grapheme, recognizers-text-choice, botbuilder-dialogs, colorhash, configparser, Flask-Cors, SQLAlchemy, psutil, Flask-MonitoringDashboard, geojson, gunicorn, kiwisolver, kneed, pyowm, pyparsing
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2021.10.8
#     Uninstalling certifi-2021.10.8:

# %%
from flask import Flask, request, Response
from botbuilder.core import BotFrameworkAdapter, BotFrameworkAdapterSettings, ConversationState,MemoryStorage
from botbuilder.schema import Activity
import asyncio
from luis.luisApp import LuisConnect
import os
from logger.logger import Log


app = Flask(__name__)
loop = asyncio.get_event_loop()

bot_settings = BotFrameworkAdapterSettings("", "")
bot_adapter = BotFrameworkAdapter(bot_settings)

#CON_MEMORY = ConversationState(MemoryStorage())
luis_bot_dialog = LuisConnect()


@app.route("/api/messages", methods=["POST"])
def messages():
    if "application/json" in request.headers["content-type"]:
        log=Log()
        request_body = request.json
        user_says = Activity().deserialize(request_body)
        log.write_log(sessionID='session1',log_message="user says: "+str(user_says))
        authorization_header = (request.headers["Authorization"] if "Authorization" in request.headers else "")

        async def call_user_fun(turncontext):
            await luis_bot_dialog.on_turn(turncontext)

        task = loop.create_task(
            bot_adapter.process_activity(user_says, authorization_header, call_user_fun)
        )
        loop.run_until_complete(task)
        return ""
    else:
        return Response(status=406)  # status for Not Acceptable




if __name__ == '__main__':
    #app.run(port= 3978)
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [08/Dec/2021 21:58:30] "POST /api/messages HTTP/1.1" 200 -
# Datetime with no tzinfo will be considered UTC.
# 127.0.0.1 - - [08/Dec/2021 21:58:45] "POST /api/messages HTTP/1.1" 200 -
# Datetime with no tzinfo will be considered UTC.
# 127.0.0.1 - - [08/Dec/2021 21:59:05] "POST /api/messages HTTP/1.1" 200 -

# %%
# !pip install pyowm
# Out:
# Collecting pyowm
#   Downloading pyowm-3.2.0-py3-none-any.whl (3.1 MB)
# Requirement already satisfied: PySocks<2,>=1.7.1 in c:\programdata\anaconda3\lib\site-packages (from pyowm) (1.7.1)
# Requirement already satisfied: requests<3,>=2.20.0 in c:\programdata\anaconda3\lib\site-packages (from pyowm) (2.24.0)
# Collecting geojson<3,>=2.3.0
#   Using cached geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.20.0->pyowm) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.20.0->pyowm) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.20.0->pyowm) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.20.0->pyowm) (3.0.4)
# Installing collected packages: geojson, pyowm
# Successfully installed geojson-2.5.0 pyowm-3.2.0

# %%
# !pip install pyowm==2.10.0
# Out:
# Collecting pyowm==2.10.0
#   Using cached pyowm-2.10.0-py3-none-any.whl (3.7 MB)
# Requirement already satisfied: requests<3,>=2.20.0 in c:\programdata\anaconda3\lib\site-packages (from pyowm==2.10.0) (2.24.0)
# Requirement already satisfied: geojson<3,>=2.3.0 in c:\programdata\anaconda3\lib\site-packages (from pyowm==2.10.0) (2.5.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.20.0->pyowm==2.10.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.20.0->pyowm==2.10.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.20.0->pyowm==2.10.0) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.20.0->pyowm==2.10.0) (1.25.11)
# Installing collected packages: pyowm
#   Attempting uninstall: pyowm
#     Found existing installation: pyowm 3.2.0
#     Uninstalling pyowm-3.2.0:
#       Successfully uninstalled pyowm-3.2.0
# Successfully installed pyowm-2.10.0

# %%
import nest_asyncio
nest_asyncio.apply()
__import__('IPython').embed()
# Out:
# Python 3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]
# Type 'copyright', 'credits' or 'license' for more information
# IPython 7.19.0 -- An enhanced Interactive Python. Type '?' for help.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-435d7df75970> in <module>
#       1 import nest_asyncio
#       2 nest_asyncio.apply()
# ----> 3 __import__('IPython').embed()
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\terminal\embed.py in embed(**kwargs)
#     386     shell = InteractiveShellEmbed.instance(_init_location_id='%s:%s' % (
#     387         frame.f_code.co_filename, frame.f_lineno), **kwargs)
# --> 388     shell(header=header, stack_depth=2, compile_flags=compile_flags,
#     389         _call_location_id='%s:%s' % (frame.f_code.co_filename, frame.f_lineno))
#     390     InteractiveShellEmbed.clear_instance()
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\terminal\embed.py in __call__(self, header, local_ns, module, dummy, stack_depth, global_ns, compile_flags, **kw)
#     226         # Call the embedding code with a stack depth of 1 so it can skip over
#     227         # our call and get the original caller's namespaces.
# --> 228         self.mainloop(local_ns, module, stack_depth=stack_depth,
#     229                       global_ns=global_ns, compile_flags=compile_flags)
#     230
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\terminal\embed.py in mainloop(self, local_ns, module, stack_depth, display_banner, global_ns, compile_flags)
#     322
#     323         with self.builtin_trap, self.display_trap:
# --> 324             self.interact()
#     325
#     326         # now, purge out the local namespace of IPython's hidden variables.
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\terminal\interactiveshell.py in interact(self, display_banner)
#     545
#     546             try:
# --> 547                 code = self.prompt_for_code()
#     548             except EOFError:
#     549                 if (not self.confirm_exit) \
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\terminal\interactiveshell.py in prompt()
#     288             def prompt():
#     289                 prompt_text = "".join(x[1] for x in self.prompts.in_prompt_tokens())
# --> 290                 lines = [input(prompt_text)]
#     291                 prompt_continuation = "".join(x[1] for x in self.prompts.continuation_prompt_tokens())
#     292                 while self.check_complete('\n'.join(lines))[0] == 'incomplete':
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\utils\py3compat.py in input(prompt)
#     145 # to forward requests to a frontend.
#     146 def input(prompt=''):
# --> 147     return builtin_mod.input(prompt)
#     148
#     149 builtin_mod_name = "builtins"
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
